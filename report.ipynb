# %%
import torch
import numpy as np
from swag import run_SWAG
from definitions import DATASETS
from swag_mod import run_MCSWAG
from noisy_adam import run_noisy_ADAM

# %%
seed = 556

# %%
DSELECTED = [
    'boston_housing',
    'concrete',
    'energy_heating_load',
    'power',
    'wine',
    'yacht',
    'kin8nm',
    'naval_compressor_decay',
    'protein',
    'year_prediction_msd',
            ]
DSELECTED
# Out:
# ['boston_housing',
#  'concrete',
#  'energy_heating_load',
#  'power',
#  'wine',
#  'yacht',
#  'kin8nm',
#  'naval_compressor_decay',
#  'protein',
#  'year_prediction_msd']

# %%
for dataset_name in DSELECTED:
    print(f"Dataset: {dataset_name}")
    torch.manual_seed(seed)
    np.random.seed(seed)
    run_SWAG(dataset_name)
    torch.manual_seed(seed)
    np.random.seed(seed)
    run_MCSWAG(dataset_name)
    torch.manual_seed(seed)
    np.random.seed(seed)
    run_noisy_ADAM(dataset_name)
# Out:
# Dataset: boston_housing
#       SWAG Test | RMSE: 2.876, PICP: 0.353, MPIW:2.795
#     MCSWAG Test | RMSE: 3.290, PICP: 0.569, MPIW:6.530
# Noisy ADAM Test | RMSE: 2.708, PICP: 0.471, MPIW:3.357
# Dataset: concrete
#       SWAG Test | RMSE: 5.681, PICP: 0.835, MPIW:16.086
#     MCSWAG Test | RMSE: 7.928, PICP: 0.728, MPIW:20.080
# Noisy ADAM Test | RMSE: 13.903, PICP: 0.010, MPIW:0.505
# Dataset: energy_heating_load
#       SWAG Test | RMSE: 1.982, PICP: 0.818, MPIW:5.064
#     MCSWAG Test | RMSE: 1.687, PICP: 0.857, MPIW:6.574
# Noisy ADAM Test | RMSE: 2.220, PICP: 0.909, MPIW:11.236
# Dataset: power
#       SWAG Test | RMSE: 4.189, PICP: 0.716, MPIW:8.820
#     MCSWAG Test | RMSE: 4.174, PICP: 0.343, MPIW:4.044
# Noisy ADAM Test | RMSE: 4.174, PICP: 0.641, MPIW:7.906
# Dataset: wine
#       SWAG Test | RMSE: 0.661, PICP: 0.194, MPIW:0.354
#     MCSWAG Test | RMSE: 0.682, PICP: 0.069, MPIW:0.121
# Noisy ADAM Test | RMSE: 0.662, PICP: 0.356, MPIW:0.677
# Dataset: yacht
#       SWAG Test | RMSE: 2.016, PICP: 0.645, MPIW:4.225
#     MCSWAG Test | RMSE: 2.046, PICP: 1.000, MPIW:6.392
# Noisy ADAM Test | RMSE: 15.476, PICP: 0.032, MPIW:0.666
# Dataset: kin8nm
#       SWAG Test | RMSE: 0.133, PICP: 0.906, MPIW:0.555
#     MCSWAG Test | RMSE: 0.122, PICP: 0.617, MPIW:0.188
# Noisy ADAM Test | RMSE: 0.114, PICP: 0.593, MPIW:0.161
# Dataset: naval_compressor_decay
#       SWAG Test | RMSE: 0.025, PICP: 0.000, MPIW:0.003
#     MCSWAG Test | RMSE: 0.025, PICP: 0.000, MPIW:0.015
# Noisy ADAM Test | RMSE: 0.008, PICP: 0.052, MPIW:0.005
# Dataset: protein
#       SWAG Test | RMSE: 4.877, PICP: 0.214, MPIW:3.187
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14727/1344089022.py in <module>
#       6     torch.manual_seed(seed)
#       7     np.random.seed(seed)
# ----> 8     run_MCSWAG(dataset_name)
#       9     torch.manual_seed(seed)
#      10     np.random.seed(seed)
#
# ~/phd/ProbAI/homework/probai2021/swag_mod.py in run_MCSWAG(dataset_name, weight_decay, lr, K, S, multiplier, verbose)
#     185             sigma_diag = torch.clamp(sigma_diag, min=1e-10)
#     186             rmse_test, pcip_test, mpiw_test = sample_and_get_metrics(
# --> 187                 x_train, y_train, x_test, y_test, model, theta_swa, sigma_diag, D, K, S, y_scaler
#     188             )
#     189             rmse_val, pcip_val, mpiw_val = sample_and_get_metrics(
#
# ~/phd/ProbAI/homework/probai2021/swag_mod.py in sample_and_get_metrics(x_train, y_train, x_test, y_test, model, theta_swa, sigma_diag, D, K, S, y_scaler)
#     121
#     122 def sample_and_get_metrics(x_train, y_train, x_test, y_test, model, theta_swa, sigma_diag, D, K, S, y_scaler):
# --> 123     samples = sample_from_SWAG(x_train, y_train, x_test, y_test, model, theta_swa, sigma_diag, D, K, S)
#     124     samples_array = np.concatenate(samples, axis=1)
#     125     y_pred = samples_array.mean(axis=1, keepdims=True)
#
# ~/phd/ProbAI/homework/probai2021/swag.py in sample_from_SWAG(x_train, y_train, x_test, y_test, model, theta_swa, sigma_diag, D, K, S)
#      90         torch.nn.utils.vector_to_parameters(sampled_weights, model.parameters())
#      91         model.to(device)
# ---> 92         test_predictions_list.append(get_test_predictions(x_train, y_train, x_test, y_test, model))
#      93     return test_predictions_list
#      94
#
# ~/phd/ProbAI/homework/probai2021/training.py in get_test_predictions(x_train, y_train, x_test, y_test, model, batch_size)
#      78 ):
#      79     _, test_loader = get_loaders(x_train, y_train, x_test, y_test, batch_size)
# ---> 80     test_predictions = [model(batch_x.to(device)).cpu().detach().numpy() for batch_x, _ in test_loader]
#      81     return np.concatenate(test_predictions)
#
# ~/phd/ProbAI/homework/probai2021/training.py in <listcomp>(.0)
#      78 ):
#      79     _, test_loader = get_loaders(x_train, y_train, x_test, y_test, batch_size)
# ---> 80     test_predictions = [model(batch_x.to(device)).cpu().detach().numpy() for batch_x, _ in test_loader]
#      81     return np.concatenate(test_predictions)
#
# ~/.virtualenvs/probai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.virtualenvs/probai/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~/.virtualenvs/probai/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.virtualenvs/probai/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/.virtualenvs/probai/lib/python3.7/site-packages/torch/utils/data/dataset.py in __getitem__(self, index)
#     207
#     208     def __getitem__(self, index):
# --> 209         return tuple(tensor[index] for tensor in self.tensors)
#     210
#     211     def __len__(self):
#
# ~/.virtualenvs/probai/lib/python3.7/site-packages/torch/utils/data/dataset.py in <genexpr>(.0)
#     207
#     208     def __getitem__(self, index):
# --> 209         return tuple(tensor[index] for tensor in self.tensors)
#     210
#     211     def __len__(self):
#
# KeyboardInterrupt:

# %%
"""
Dataset: boston_housing
      SWAG Test | RMSE: 2.876, PICP: 0.353, MPIW:2.795
    MCSWAG Test | RMSE: 3.290, PICP: 0.569, MPIW:6.530 
Noisy ADAM Test | RMSE: 2.708, PICP: 0.471, MPIW:3.357
Dataset: concrete
      SWAG Test | RMSE: 5.681, PICP: 0.835, MPIW:16.086
    MCSWAG Test | RMSE: 7.928, PICP: 0.728, MPIW:20.080 
Noisy ADAM Test | RMSE: 13.903, PICP: 0.010, MPIW:0.505
Dataset: energy_heating_load
      SWAG Test | RMSE: 1.982, PICP: 0.818, MPIW:5.064
    MCSWAG Test | RMSE: 1.687, PICP: 0.857, MPIW:6.574 
Noisy ADAM Test | RMSE: 2.220, PICP: 0.909, MPIW:11.236
Dataset: power
      SWAG Test | RMSE: 4.189, PICP: 0.716, MPIW:8.820
    MCSWAG Test | RMSE: 4.174, PICP: 0.343, MPIW:4.044 
Noisy ADAM Test | RMSE: 4.174, PICP: 0.641, MPIW:7.906
Dataset: wine
      SWAG Test | RMSE: 0.661, PICP: 0.194, MPIW:0.354
    MCSWAG Test | RMSE: 0.682, PICP: 0.069, MPIW:0.121 
Noisy ADAM Test | RMSE: 0.662, PICP: 0.356, MPIW:0.677
Dataset: yacht
      SWAG Test | RMSE: 2.016, PICP: 0.645, MPIW:4.225
    MCSWAG Test | RMSE: 2.046, PICP: 1.000, MPIW:6.392 
Noisy ADAM Test | RMSE: 15.476, PICP: 0.032, MPIW:0.666
Dataset: kin8nm
      SWAG Test | RMSE: 0.133, PICP: 0.906, MPIW:0.555
    MCSWAG Test | RMSE: 0.122, PICP: 0.617, MPIW:0.188 
Noisy ADAM Test | RMSE: 0.114, PICP: 0.593, MPIW:0.161
Dataset: naval_compressor_decay
      SWAG Test | RMSE: 0.025, PICP: 0.000, MPIW:0.003
    MCSWAG Test | RMSE: 0.025, PICP: 0.000, MPIW:0.015 
Noisy ADAM Test | RMSE: 0.008, PICP: 0.052, MPIW:0.005

"""

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn

from data import get_loaders, load_dataset, train_test_split
from definitions import device
from metrics import RMSE
from models import create_model, load_model
from training import get_test_predictions, test_step
from utils import print_losses
from swag_mod import train_SWAG_mod, calculate_coeffs, sample_and_get_metrics

# %%
K = 10
S = 500
weight_decay = 0.
multiplier = 2
tolerance = 0.05
classic = False

# for dataset_name in DATASETS:
for classic in [True, False]:
    for dataset_name in ['energy_heating_load']:
        run_SWAG(dataset_name, weight_decay=0, train_model_flag=False)
        for tolerance in [0.05]:
            print(classic)
            print(f"""-----> TOLERANCE: {tolerance}""")
            x_train, y_train, x_test, y_test, x_scaler, y_scaler = load_dataset(dataset_name, verbose=False)
            batch_size = x_train.shape[0]//9
            model = create_model(x_train, layer_dims=[50], verbose=False)
            model = load_model(model, f"best_model_weights-{dataset_name}.pth", verbose=False)
            y_pred = get_test_predictions(x_train, y_train, x_test, y_test, model)
            theta_epoch = torch.nn.utils.parameters_to_vector(model.parameters()).detach().cpu().clone()
            lr_multipliers = torch.ones_like(theta_epoch).float()
            for rounds in range(10):
                try:
                    model = load_model(model, f"best_model_weights-{dataset_name}.pth", verbose=False)
                    theta_swa, sigma_diag, D, thetas = train_SWAG_mod(x_train, y_train, x_test, y_test, model, K, lr_multipliers,
                                                                  verbose=False, lr=0.01, batch_size=batch_size, 
                                                                  weight_decay=weight_decay, epochs=50)
                    weight_series = torch.stack(thetas).numpy()
                    step_plot = weight_series.shape[1] // 3
                    weight_series -= weight_series.mean(axis=0, keepdims=True)
                    weight_series /= weight_series.std(axis=0, keepdims=True) + 1e-10
                    plt.plot(weight_series[:,::step_plot], alpha=0.7)
                    plt.show()
                    coeffs = calculate_coeffs(weight_series, False)
                    if classic:
                        lr_multipliers *= multiplier
                    else:
                         lr_multipliers[np.abs(coeffs) > tolerance] *= multiplier
                    _, x_val, _, y_val = train_test_split(x_train, y_train, test_size=0.1)
                    y_val_pred = model(torch.from_numpy(x_val).float().to(device)).detach().cpu().numpy()
                    sigma_diag = torch.clamp(sigma_diag, min=1e-10)
                    rmse_test, pcip_test, mpiw_test = sample_and_get_metrics(x_train, y_train, x_test, y_test, 
                                                                             model, theta_swa, sigma_diag, D, K, S, y_scaler)
                    rmse_val, pcip_val, mpiw_val = sample_and_get_metrics(x_train, y_train, x_val, y_val, 
                                                                             model, theta_swa, sigma_diag, D, K, S, y_scaler)
                    print(f"val: {rmse_val:.4f}, test: {rmse_test:.4f}")
                except ValueError as e:
                    pass
# Out:
#       SWAG Test | RMSE: 2.045, PICP: 0.766, MPIW:3.486
# True
# -----> TOLERANCE: 0.05
# val: 2.7492, test: 2.1181
# val: 2.7173, test: 2.0832
# val: 2.6828, test: 2.0704
# val: 2.6047, test: 2.0468
# val: 2.4931, test: 1.8399
# val: 2.4535, test: 1.8249
#       SWAG Test | RMSE: 2.085, PICP: 0.753, MPIW:3.915
# False
# -----> TOLERANCE: 0.05
# val: 2.7451, test: 2.1226
# val: 2.7150, test: 2.0818
# val: 2.6915, test: 2.0689
# val: 2.6335, test: 2.0278
# val: 2.5170, test: 1.9123
# val: 2.4108, test: 1.7065
# val: 2.2774, test: 1.6339
# val: 2.3112, test: 1.7080
# val: 2.3945, test: 1.7601
